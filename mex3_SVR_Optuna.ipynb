# %% [markdown]
# # Machine Exercise 3
# ## Miguel Luis Martinez, Juan Carlos Roldan, Jeryl Salas | AI 221 WZZQ  Shannon Batch | University of the Philippines Diliman

# %%
# download and import dependencies
# !pip install ucimlrepo optuna

from ucimlrepo import fetch_ucirepo

import optuna
import pandas as pd
import seaborn as sns
import numpy as np
from time import perf_counter
from optuna.samplers import TPESampler
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC, SVR
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,mean_squared_error,r2_score
from sklearn.model_selection import KFold
# Out:
# Requirement already satisfied: ucimlrepo in /usr/local/lib/python3.10/dist-packages (0.0.7)
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.0.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2.1.4)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2024.8.30)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.13.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.35)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)

# %% [markdown]
# # Loading the Dataset
# The Wine Quality dataset downloaded from https://archive.ics.uci.edu/ml/datasets/wine+quality consists of 6497 entries split into 1599 samples of red Portuguese "Vinho Verde" wine and 4898 samples of white Portuguese "Vinho Verde" wine. For this machine exercise, only the red wine samples will be used.

# %%
# fetch dataset as pandas dataframe
wine_quality = fetch_ucirepo(id=186).data.original
# use a downloaded dataset
#wine_quality = pd.read_csv("winequality-red.csv",sep=";")
#show dataset
print("Original Dataset")
display(wine_quality)
#restrict data to red wine
if "color" in wine_quality.columns:
    wine_quality = wine_quality[wine_quality["color"]=="red"]
    wine_quality = wine_quality.loc[:,wine_quality.columns!="color"]
print("Filtered Dataset")
display(wine_quality)
# data (as pandas dataframes)
X = wine_quality.iloc[:,:-1]
y = wine_quality.iloc[:,-1:]
# Out:
# Original Dataset
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  color
# 0         9.4        5    red
# 1         9.8        5    red
# 2         9.8        5    red
# 3         9.8        6    red
# 4         9.4        5    red
# ...       ...      ...    ...
# 6492     11.2        6  white
# 6493      9.6        5  white
# 6494      9.4        6  white
# 6495     12.8        7  white
# 6496     11.8        6  white
#
# [6497 rows x 13 columns]
# Filtered Dataset
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
data = X.copy()
data['target'] = y
#sns.pairplot(data, hue='target')
#sns.histplot(data, x='fixed_acidity')

# %% [markdown]
# ## Problem a.
# * Randomly split red wine dataset into 70% train and 30% test with stratify=y.

# %%
#Use a seed for random state
wine_seed = 42 #seed used for splitting the training and testing data
tune_seed = 420 #seed used for hyperparameter tuning
cv_seed = 420 #seed used for K-fold cross validation
pipe_seed = 6591 #seed used for classifier and regressor pipelines
#uncomment to generate a new seed
#wine_seed = np.random.randint((2**31)-1)
#cv_seed = np.random.randint((2**31)-1)
#tune_seed = np.random.randint((2**31)-1)
#pipe_seed = np.random.randint((2**31)-1)
print(f"Wine Dataset Splitter Seed: {wine_seed}")
print(f"Cross-Validation Seed: {cv_seed}")
print(f"Tuning Seed: {tune_seed}")
print(f"Classifier Seed: {pipe_seed}")

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=wine_seed, stratify=y)
# Out:
# Wine Dataset Splitter Seed: 42
# Cross-Validation Seed: 420
# Tuning Seed: 420
# Classifier Seed: 6591

# %% [markdown]
# * Build a pipeline with Standard scaler then SVC.
# * Design hyper-parameter tuning procedure to automatically find the model with the best cross-validation accuracy.
#
# For hyperparameter tuning, Optuna was used to find the optimal set of hyperparameters within a certain range in 100 trials. The hyperparameters that were tuned were the regularization parameter C (from 0 to 2 in intervals of 0.001), the kernel (linear, rbf, or sigmoid), the kernel coefficient gamma (from 0 to 10 in intervals of 0.0001). Cross-validation was performed via the sklearn cross_val_score using the default 5-fold cross-validation
# settings.
#
# As shown below, the best classifier model found used the Radial Basis Function kernel and had a regularization parameter of 1.598 and a kernel coefficient of 0.949.

# %%
# Using Optuna to optimize hyperparameters
def objective(trial):
    C = trial.suggest_float("C",0,2,step=0.001)
    kernel = trial.suggest_categorical("kernel", ['rbf', 'sigmoid'])
    gamma = trial.suggest_float("gamma",0,10,step=0.0001)
    pipeline = Pipeline([
        ('standard_scaler', StandardScaler()),
        ('classifier', SVC(kernel=kernel,gamma=gamma,random_state=pipe_seed))
    ])
    cv = StratifiedKFold(n_splits=5,shuffle=True,random_state=cv_seed)
    #Return the mean score across all folds
    cv_score = cross_val_score(pipeline,X_train,y_train.values.ravel(),scoring="accuracy",cv=cv)
    print(cv_score)
    return np.mean(cv_score)

study = optuna.create_study(direction="maximize",sampler=TPESampler(seed=tune_seed))
study.optimize(objective, n_trials=100)

trial = study.best_trial

print(f"Best Classifier Mean Accuracy: {study.best_trial.values}")
print(f"Best Classifier Parameters:")
for param in study.best_trial.params.items():
    print(f"{param[0]}: {param[1]}")

#Reconstruct the best classifier
estimators_c = [
    ('standard_scaler', StandardScaler()),
    ('classifier', SVC(**study.best_trial.params,random_state=pipe_seed))
]
pipeline_c = Pipeline(estimators_c)
pipeline_c.fit(X_train,y_train.values.ravel())
# Out:
# [I 2024-09-22 10:40:21,078] A new study created in memory with name: no-name-e7c7788d-dc37-4b2b-94f6-84818cf45dcc
# [I 2024-09-22 10:40:23,511] Trial 0 finished with value: -0.4481595639745886 and parameters: {'C': 3.2, 'kernel': 'linear', 'gamma': 8.700000000000001, 'epsilon': 0.63}. Best is trial 0 with value: -0.4481595639745886.
# [I 2024-09-22 10:40:24,762] Trial 1 finished with value: -0.46174337876582944 and parameters: {'C': 3.6, 'kernel': 'rbf', 'gamma': 0.9, 'epsilon': 0.056}. Best is trial 1 with value: -0.46174337876582944.
# [I 2024-09-22 10:40:25,576] Trial 2 finished with value: -0.5795284477329286 and parameters: {'C': 2.4000000000000004, 'kernel': 'rbf', 'gamma': 3.5, 'epsilon': 0.46900000000000003}. Best is trial 2 with value: -0.5795284477329286.
# [I 2024-09-22 10:40:29,802] Trial 3 finished with value: -0.4474304496840385 and parameters: {'C': 7.7, 'kernel': 'linear', 'gamma': 7.6000000000000005, 'epsilon': 0.441}. Best is trial 2 with value: -0.5795284477329286.
# [I 2024-09-22 10:40:33,383] Trial 4 finished with value: -0.44098783868240166 and parameters: {'C': 2.2, 'kernel': 'linear', 'gamma': 4.4, 'epsilon': 0.289}. Best is trial 2 with value: -0.5795284477329286.
# [I 2024-09-22 10:40:34,050] Trial 5 finished with value: -0.640475205165858 and parameters: {'C': 2.8000000000000003, 'kernel': 'rbf', 'gamma': 6.5, 'epsilon': 0.726}. Best is trial 5 with value: -0.640475205165858.
# [I 2024-09-22 10:40:34,945] Trial 6 finished with value: -557862.3894509334 and parameters: {'C': 9.4, 'kernel': 'sigmoid', 'gamma': 6.800000000000001, 'epsilon': 0.314}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:35,917] Trial 7 finished with value: -373790.402319747 and parameters: {'C': 7.9, 'kernel': 'sigmoid', 'gamma': 3.4000000000000004, 'epsilon': 0.551}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:41,268] Trial 8 finished with value: -0.44313577222133677 and parameters: {'C': 8.2, 'kernel': 'linear', 'gamma': 7.1000000000000005, 'epsilon': 0.321}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:48,808] Trial 9 finished with value: -0.45138978689623094 and parameters: {'C': 5.5, 'kernel': 'linear', 'gamma': 7.300000000000001, 'epsilon': 0.051000000000000004}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:49,840] Trial 10 finished with value: -58.39689283363574 and parameters: {'C': 0.1, 'kernel': 'sigmoid', 'gamma': 10.0, 'epsilon': 0.999}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:50,379] Trial 11 finished with value: -550789.6294986941 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 2.4000000000000004, 'epsilon': 0.6950000000000001}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:50,881] Trial 12 finished with value: -305899.81722730846 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 0.6000000000000001, 'epsilon': 0.8}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:51,387] Trial 13 finished with value: -536018.5724141088 and parameters: {'C': 9.9, 'kernel': 'sigmoid', 'gamma': 2.0, 'epsilon': 0.24}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:51,852] Trial 14 finished with value: -237262.2598825164 and parameters: {'C': 6.3, 'kernel': 'sigmoid', 'gamma': 5.5, 'epsilon': 0.907}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:52,774] Trial 15 finished with value: -456279.75930577563 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 2.3000000000000003, 'epsilon': 0.654}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:53,882] Trial 16 finished with value: -230407.4328504921 and parameters: {'C': 6.2, 'kernel': 'sigmoid', 'gamma': 5.5, 'epsilon': 0.168}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:54,513] Trial 17 finished with value: -290637.5046215005 and parameters: {'C': 7.0, 'kernel': 'sigmoid', 'gamma': 4.4, 'epsilon': 0.39}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:54,624] Trial 18 finished with value: -0.6581144080717489 and parameters: {'C': 9.0, 'kernel': 'sigmoid', 'gamma': 0.0, 'epsilon': 0.5660000000000001}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:55,077] Trial 19 finished with value: -527418.2525357093 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 8.8, 'epsilon': 0.8160000000000001}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:55,561] Trial 20 finished with value: -0.5147916407485211 and parameters: {'C': 4.3999999999999995, 'kernel': 'rbf', 'gamma': 2.2, 'epsilon': 0.168}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:56,055] Trial 21 finished with value: -455189.88221413025 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 2.0, 'epsilon': 0.231}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:40:56,532] Trial 22 finished with value: -588269.4516880662 and parameters: {'C': 9.9, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.378}. Best is trial 22 with value: -588269.4516880662.
# [I 2024-09-22 10:40:57,000] Trial 23 finished with value: -592602.6592383563 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.6, 'epsilon': 0.373}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:40:57,552] Trial 24 finished with value: -426392.1561724226 and parameters: {'C': 8.4, 'kernel': 'sigmoid', 'gamma': 3.8000000000000003, 'epsilon': 0.34500000000000003}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:40:58,246] Trial 25 finished with value: -330963.8940882996 and parameters: {'C': 7.4, 'kernel': 'sigmoid', 'gamma': 6.300000000000001, 'epsilon': 0.394}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:40:58,963] Trial 26 finished with value: -297083.8213565023 and parameters: {'C': 7.0, 'kernel': 'sigmoid', 'gamma': 4.9, 'epsilon': 0.533}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:40:59,740] Trial 27 finished with value: -598507.7013597384 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.179}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:00,513] Trial 28 finished with value: -420948.3111505824 and parameters: {'C': 8.4, 'kernel': 'sigmoid', 'gamma': 2.9000000000000004, 'epsilon': 0.131}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:00,994] Trial 29 finished with value: -0.46393195525296865 and parameters: {'C': 1.3000000000000003, 'kernel': 'rbf', 'gamma': 1.1, 'epsilon': 0.226}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:04,703] Trial 30 finished with value: -0.4519417519218056 and parameters: {'C': 10.0, 'kernel': 'linear', 'gamma': 4.1000000000000005, 'epsilon': 0.006}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:05,175] Trial 31 finished with value: -520271.0475576531 and parameters: {'C': 9.3, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.289}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:05,650] Trial 32 finished with value: -537318.0323621857 and parameters: {'C': 9.4, 'kernel': 'sigmoid', 'gamma': 5.1000000000000005, 'epsilon': 0.40900000000000003}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:06,095] Trial 33 finished with value: -468221.2881626886 and parameters: {'C': 8.6, 'kernel': 'sigmoid', 'gamma': 8.4, 'epsilon': 0.494}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:06,522] Trial 34 finished with value: -0.4842191891865227 and parameters: {'C': 9.5, 'kernel': 'rbf', 'gamma': 1.6, 'epsilon': 0.10200000000000001}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:07,017] Trial 35 finished with value: -351242.98969672667 and parameters: {'C': 7.7, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.352}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:07,491] Trial 36 finished with value: -96704.23178671348 and parameters: {'C': 4.0, 'kernel': 'sigmoid', 'gamma': 4.7, 'epsilon': 0.263}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:09,215] Trial 37 finished with value: -0.4474141396572288 and parameters: {'C': 8.6, 'kernel': 'linear', 'gamma': 6.2, 'epsilon': 0.47200000000000003}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:09,668] Trial 38 finished with value: -0.5768807681919949 and parameters: {'C': 9.5, 'kernel': 'rbf', 'gamma': 3.6, 'epsilon': 0.436}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:10,137] Trial 39 finished with value: -388207.16334727686 and parameters: {'C': 8.1, 'kernel': 'sigmoid', 'gamma': 5.7, 'epsilon': 0.17500000000000002}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:13,022] Trial 40 finished with value: -0.4420624502545209 and parameters: {'C': 7.2, 'kernel': 'linear', 'gamma': 7.800000000000001, 'epsilon': 0.302}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:13,799] Trial 41 finished with value: -558168.4833026279 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 2.7, 'epsilon': 0.624}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:41:14,378] Trial 42 finished with value: -599871.2813134261 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.615}. Best is trial 42 with value: -599871.2813134261.
# [I 2024-09-22 10:41:14,851] Trial 43 finished with value: -588320.0653785786 and parameters: {'C': 9.9, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.593}. Best is trial 42 with value: -599871.2813134261.
# [I 2024-09-22 10:41:15,342] Trial 44 finished with value: -602504.053701971 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.4000000000000004, 'epsilon': 0.597}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:15,814] Trial 45 finished with value: -455382.5487691623 and parameters: {'C': 8.7, 'kernel': 'sigmoid', 'gamma': 4.1000000000000005, 'epsilon': 0.602}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:16,317] Trial 46 finished with value: -501030.11245069356 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 1.5, 'epsilon': 0.741}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:16,790] Trial 47 finished with value: -389064.83868852555 and parameters: {'C': 8.0, 'kernel': 'sigmoid', 'gamma': 3.8000000000000003, 'epsilon': 0.674}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:17,282] Trial 48 finished with value: -498251.85632847407 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.588}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:17,902] Trial 49 finished with value: -0.44779137888888193 and parameters: {'C': 2.0, 'kernel': 'linear', 'gamma': 2.5, 'epsilon': 0.517}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:18,396] Trial 50 finished with value: -165191.66204479587 and parameters: {'C': 5.3, 'kernel': 'sigmoid', 'gamma': 4.6000000000000005, 'epsilon': 0.731}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:18,872] Trial 51 finished with value: -600754.141260461 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.46}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:19,366] Trial 52 finished with value: -544403.365848628 and parameters: {'C': 9.5, 'kernel': 'sigmoid', 'gamma': 4.1000000000000005, 'epsilon': 0.459}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:19,840] Trial 53 finished with value: -554009.8898993005 and parameters: {'C': 9.6, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.556}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:20,341] Trial 54 finished with value: -424311.4935963005 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 1.7000000000000002, 'epsilon': 0.637}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:20,825] Trial 55 finished with value: -568306.6201866537 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 2.6, 'epsilon': 0.7000000000000001}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:21,210] Trial 56 finished with value: -0.6493859365189906 and parameters: {'C': 9.2, 'kernel': 'rbf', 'gamma': 3.7, 'epsilon': 0.775}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:21,698] Trial 57 finished with value: -235436.781207568 and parameters: {'C': 6.3, 'kernel': 'sigmoid', 'gamma': 4.3, 'epsilon': 0.51}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:22,191] Trial 58 finished with value: -559137.0065343828 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.5640000000000001}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:22,683] Trial 59 finished with value: -457524.26174567157 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 2.2, 'epsilon': 0.422}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:23,189] Trial 60 finished with value: -401213.3789537899 and parameters: {'C': 8.2, 'kernel': 'sigmoid', 'gamma': 5.2, 'epsilon': 0.594}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:41:23,663] Trial 61 finished with value: -607780.1194238723 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.5, 'epsilon': 0.362}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:24,206] Trial 62 finished with value: -601012.0324420196 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.4000000000000004, 'epsilon': 0.34800000000000003}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:24,944] Trial 63 finished with value: -520679.21141541144 and parameters: {'C': 9.3, 'kernel': 'sigmoid', 'gamma': 3.9000000000000004, 'epsilon': 0.341}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:25,706] Trial 64 finished with value: -548842.2168828282 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 2.7, 'epsilon': 0.366}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:26,494] Trial 65 finished with value: -58054.79293540269 and parameters: {'C': 3.1, 'kernel': 'sigmoid', 'gamma': 3.5, 'epsilon': 0.465}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:27,277] Trial 66 finished with value: -422222.40348371706 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 1.9000000000000001, 'epsilon': 0.488}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:27,847] Trial 67 finished with value: -523775.7969073887 and parameters: {'C': 9.3, 'kernel': 'sigmoid', 'gamma': 4.5, 'epsilon': 0.2}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:28,377] Trial 68 finished with value: -0.5462254023101568 and parameters: {'C': 10.0, 'kernel': 'rbf', 'gamma': 3.0, 'epsilon': 0.269}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:30,164] Trial 69 finished with value: -0.4467900409002718 and parameters: {'C': 7.7, 'kernel': 'linear', 'gamma': 1.1, 'epsilon': 0.398}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:30,655] Trial 70 finished with value: -434475.3969667024 and parameters: {'C': 8.5, 'kernel': 'sigmoid', 'gamma': 3.5, 'epsilon': 0.315}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:31,139] Trial 71 finished with value: -563047.5930359515 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 3.2, 'epsilon': 0.537}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:31,655] Trial 72 finished with value: -562203.8587457169 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 2.4000000000000004, 'epsilon': 0.655}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:41:32,145] Trial 73 finished with value: -609468.262535682 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 4.0, 'epsilon': 0.621}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:41:32,636] Trial 74 finished with value: -517385.97092437913 and parameters: {'C': 9.4, 'kernel': 'sigmoid', 'gamma': 4.0, 'epsilon': 0.066}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:41:33,108] Trial 75 finished with value: -1487.3003666495813 and parameters: {'C': 0.5, 'kernel': 'sigmoid', 'gamma': 4.3, 'epsilon': 0.448}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:41:33,608] Trial 76 finished with value: -201919.5330135187 and parameters: {'C': 5.9, 'kernel': 'sigmoid', 'gamma': 2.8000000000000003, 'epsilon': 0.6980000000000001}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:41:34,089] Trial 77 finished with value: -474366.6735904572 and parameters: {'C': 8.8, 'kernel': 'sigmoid', 'gamma': 4.9, 'epsilon': 0.875}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:41:34,569] Trial 78 finished with value: -515759.19682690315 and parameters: {'C': 9.2, 'kernel': 'sigmoid', 'gamma': 3.6, 'epsilon': 0.329}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:41:35,025] Trial 79 finished with value: -614475.0476215199 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 9.8, 'epsilon': 0.425}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:35,471] Trial 80 finished with value: -574690.6211358347 and parameters: {'C': 9.6, 'kernel': 'sigmoid', 'gamma': 9.700000000000001, 'epsilon': 0.421}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:35,969] Trial 81 finished with value: -598400.7372269508 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.2, 'epsilon': 0.374}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:36,420] Trial 82 finished with value: -131459.43470668438 and parameters: {'C': 4.6, 'kernel': 'sigmoid', 'gamma': 9.1, 'epsilon': 0.624}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:36,919] Trial 83 finished with value: -596070.7179196423 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.1, 'epsilon': 0.371}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:37,405] Trial 84 finished with value: -546361.212159029 and parameters: {'C': 9.5, 'kernel': 'sigmoid', 'gamma': 3.8000000000000003, 'epsilon': 0.529}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:38,149] Trial 85 finished with value: -503032.5879237243 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 2.8000000000000003, 'epsilon': 0.494}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:42,083] Trial 86 finished with value: -0.4411229544830301 and parameters: {'C': 9.8, 'kernel': 'linear', 'gamma': 2.4000000000000004, 'epsilon': 0.253}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:42,553] Trial 87 finished with value: -0.5894510871411874 and parameters: {'C': 9.4, 'kernel': 'rbf', 'gamma': 7.0, 'epsilon': 0.436}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:41:43,021] Trial 88 finished with value: -618574.1619118742 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 8.0, 'epsilon': 0.404}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:43,473] Trial 89 finished with value: -568326.0978598751 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 7.800000000000001, 'epsilon': 0.28400000000000003}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:43,931] Trial 90 finished with value: -441380.8650828355 and parameters: {'C': 8.4, 'kernel': 'sigmoid', 'gamma': 9.3, 'epsilon': 0.66}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:44,399] Trial 91 finished with value: -605597.0851467741 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.200000000000001, 'epsilon': 0.397}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:44,927] Trial 92 finished with value: -608393.3788562336 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.3, 'epsilon': 0.4}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:45,464] Trial 93 finished with value: -605596.7774656991 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.200000000000001, 'epsilon': 0.41200000000000003}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:45,922] Trial 94 finished with value: -523565.83871383 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 8.200000000000001, 'epsilon': 0.406}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:46,393] Trial 95 finished with value: -570370.634368397 and parameters: {'C': 9.5, 'kernel': 'sigmoid', 'gamma': 8.4, 'epsilon': 0.352}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:46,854] Trial 96 finished with value: -602080.1439836308 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 7.300000000000001, 'epsilon': 0.47200000000000003}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:47,329] Trial 97 finished with value: -477101.7257391604 and parameters: {'C': 8.7, 'kernel': 'sigmoid', 'gamma': 7.300000000000001, 'epsilon': 0.432}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:47,784] Trial 98 finished with value: -607512.3735038352 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.700000000000001, 'epsilon': 0.4}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:41:48,266] Trial 99 finished with value: -578828.8730697364 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 8.0, 'epsilon': 0.481}. Best is trial 88 with value: -618574.1619118742.
# Best Regressor Mean Squared Error: -618574.1619118742
# Best Regressor Parameters:
# C: 10.0
# kernel: sigmoid
# gamma: 8.0
# epsilon: 0.404
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('regressor',
#                  SVR(C=10.0, epsilon=0.404, gamma=8.0, kernel='sigmoid'))])

# %% [markdown]
# We then show the performance of the chosen classifier. As seen from the results, the classifier was able to perform really well on the training set with a 97.14% accuracy, 98.61% precision, and an F1 score of 0.9584. The performance of the classifier on the test set, on the other hand, were much lower than expected with an accuracy of 63.33%, precision of 40.49% and and F1 score of 0.3449.

# %%
y_train_predict_c = pipeline_c.predict(X_train)
print(f"Classifier Results on Train Set:")
print(f"Test Set Prediction Confusion Matrix:\n{confusion_matrix(y_train,y_train_predict_c)}")
print(f"Test Set Prediction Accuracy: {accuracy_score(y_train,y_train_predict_c):4f}")
print(f"Test Set Prediction Precision: {precision_score(y_train,y_train_predict_c,average='macro'):4f}")
print(f"Test Set Prediction Recall: {recall_score(y_train,y_train_predict_c,average='macro'):4f}")
print(f"Test Set Prediction F1 Score: {f1_score(y_train,y_train_predict_c,average='macro'):4f}")

y_test_predict_c = pipeline_c.predict(X_test)
print(f"Classifier Results on Test Set:")
print(f"Test Set Prediction Confusion Matrix:\n{confusion_matrix(y_test,y_test_predict_c)}")
print(f"Test Set Prediction Accuracy: {accuracy_score(y_test,y_test_predict_c):4f}")
print(f"Test Set Prediction Precision: {precision_score(y_test,y_test_predict_c,average='macro'):4f}")
print(f"Test Set Prediction Recall: {recall_score(y_test,y_test_predict_c,average='macro'):4f}")
print(f"Test Set Prediction F1 Score: {f1_score(y_test,y_test_predict_c,average='macro'):4f}")
# Out:
# Classifier Results on Train Set:
# Test Set Prediction Confusion Matrix:
# [[  7   0   0   0   0   0]
#  [  0  31   4   2   0   0]
#  [  0   0 471   6   0   0]
#  [  0   0  13 432   1   0]
#  [  0   0   1   3 135   0]
#  [  0   0   0   0   2  11]]
# Test Set Prediction Accuracy: 0.971403
# Test Set Prediction Precision: 0.986103
# Test Set Prediction Recall: 0.935208
# Test Set Prediction F1 Score: 0.958366
# Classifier Results on Test Set:
# Test Set Prediction Confusion Matrix:
# [[  0   1   2   0   0   0]
#  [  0   0  11   5   0   0]
#  [  0   0 156  46   2   0]
#  [  0   0  58 127   7   0]
#  [  0   0   6  33  20   1]
#  [  0   0   2   1   1   1]]
# Test Set Prediction Accuracy: 0.633333
# Test Set Prediction Precision: 0.404926
# Test Set Prediction Recall: 0.326583
# Test Set Prediction F1 Score: 0.344930
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Even with lower than expected results from the classifier, we used the appraoch of 'Modeling wine preferences by data mining from physicochemical properties,' Cortez et al. (2009) wherein the researchers evaluated distinct accuracies, allowing the degree of error, tolerance (T) is accepted. As seen from the confusion matrix, the misclassifications are mostly just one class away from the true class. And therefore, allowing to have a tolerance, T=1, would correct most of the mistakes done by the model and therefore, the testing accuracy with a tolerance of T = 1, has made the model highly accurate with 96.25% accuracy.

# %%
import numpy as np

def accuracy_with_tol(y_true, y_pred, tolerance):
    correct = 0
    for true, pred in zip(y_true, y_pred):
        if np.abs(true - pred) <= tolerance:
            correct += 1
    return correct / len(y_true)


y_true = (np.array(y_test)).tolist()
y_pred = np.array(y_test_predict_c)
tolerances = [0.1, 0.25, 0.5, 1.0]

for tolerance in tolerances:
    acc_with_tolerance = accuracy_with_tol(y_true, y_pred, tolerance)
    print(f"Accuracy with Tolerance, T = {tolerance}: {acc_with_tolerance}")

acc_without_tolerance = (y_true == y_pred).mean()
print(f"Traditional Accuracy (Classifier): {accuracy_score(y_test,y_test_predict_c):4f}")
# Out:
# Accuracy with Tolerance, T = 0.1: 0.6333333333333333
# Accuracy with Tolerance, T = 0.25: 0.6333333333333333
# Accuracy with Tolerance, T = 0.5: 0.6333333333333333
# Accuracy with Tolerance, T = 1.0: 0.9625
# Traditional Accuracy (Classifier): 0.633333

# %% [markdown]
# ## Problem b.
# * Build a pipeline with Standard scaler then SVR.
# * Design hyper-parameter tuning procedure to automatically find the model with the best cross-validation accuracy.

# %% [markdown]
# For hyperparameter tuning, Optuna was used to find the optimal set of hyperparameters within a certain range in 100 trials. Similar to the SVC in the previous item, the hyperparameters that were tuned were the regularization parameter C (from 0.1 to 10 in intervals of 0.1), the kernel (linear, rbf, or sigmoid), the kernel coefficient gamma (from 0 to 10 in intervals of 0.1), and the epsilon value (from 0 to 10 in intervals of 0.001).
#
# As shown below, the best regressor model found used the linear kernel and had a regularization parameter of 9.2, a gamma of 0.8, and an epsilon parameter of 0.091.

# %%
# Using Optuna to optimize hyperparameters
def objective(trial):
    C = trial.suggest_float("C", 0.1, 10, step=0.1)
    kernel = trial.suggest_categorical("kernel", ['linear', 'rbf', 'sigmoid'])
    gamma = trial.suggest_float("gamma", 0, 10, step=0.1)
    epsilon = trial.suggest_float("epsilon", 0, 1, step=0.001)

    pipeline = Pipeline([
        ('standard_scaler', StandardScaler()),
        ('regressor', SVR(C=C, kernel=kernel, gamma=gamma, epsilon=epsilon))
    ])

    # Use KFold instead of StratifiedKFold since you are working with regression
    cv = KFold(n_splits=5, shuffle=True, random_state=cv_seed)

    # Use a regression scoring metric such as neg_mean_squared_error or r2
    cv_score = cross_val_score(pipeline, X_train, y_train.values.ravel(), scoring="neg_mean_squared_error", cv=cv)

    # Return the mean score across all folds
    return np.mean(cv_score)


study = optuna.create_study(direction="minimize", sampler=TPESampler(seed=tune_seed))  # Minimizing error
study.optimize(objective, n_trials=100)

trial = study.best_trial

print(f"Best Regressor Mean Squared Error: {study.best_trial.value}")
print(f"Best Regressor Parameters:")
for param in study.best_trial.params.items():
    print(f"{param[0]}: {param[1]}")

# Reconstruct the best regressor
estimators_r = [
    ('standard_scaler', StandardScaler()),
    ('regressor', SVR(**study.best_trial.params))  # Remove random_state, since SVR doesn't have it
]

pipeline_r = Pipeline(estimators_r)
pipeline_r.fit(X_train, y_train.values.ravel())
# Out:
# [I 2024-09-22 10:43:33,909] A new study created in memory with name: no-name-9df852da-6be0-412e-9df9-23420181b109
# [I 2024-09-22 10:43:36,881] Trial 0 finished with value: -0.4481595639745886 and parameters: {'C': 3.2, 'kernel': 'linear', 'gamma': 8.700000000000001, 'epsilon': 0.63}. Best is trial 0 with value: -0.4481595639745886.
# [I 2024-09-22 10:43:39,015] Trial 1 finished with value: -0.46174337876582944 and parameters: {'C': 3.6, 'kernel': 'rbf', 'gamma': 0.9, 'epsilon': 0.056}. Best is trial 1 with value: -0.46174337876582944.
# [I 2024-09-22 10:43:40,630] Trial 2 finished with value: -0.5795284477329286 and parameters: {'C': 2.4000000000000004, 'kernel': 'rbf', 'gamma': 3.5, 'epsilon': 0.46900000000000003}. Best is trial 2 with value: -0.5795284477329286.
# [I 2024-09-22 10:43:44,084] Trial 3 finished with value: -0.4474304496840385 and parameters: {'C': 7.7, 'kernel': 'linear', 'gamma': 7.6000000000000005, 'epsilon': 0.441}. Best is trial 2 with value: -0.5795284477329286.
# [I 2024-09-22 10:43:44,949] Trial 4 finished with value: -0.44098783868240166 and parameters: {'C': 2.2, 'kernel': 'linear', 'gamma': 4.4, 'epsilon': 0.289}. Best is trial 2 with value: -0.5795284477329286.
# [I 2024-09-22 10:43:45,363] Trial 5 finished with value: -0.640475205165858 and parameters: {'C': 2.8000000000000003, 'kernel': 'rbf', 'gamma': 6.5, 'epsilon': 0.726}. Best is trial 5 with value: -0.640475205165858.
# [I 2024-09-22 10:43:45,794] Trial 6 finished with value: -557862.3894509334 and parameters: {'C': 9.4, 'kernel': 'sigmoid', 'gamma': 6.800000000000001, 'epsilon': 0.314}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:46,261] Trial 7 finished with value: -373790.402319747 and parameters: {'C': 7.9, 'kernel': 'sigmoid', 'gamma': 3.4000000000000004, 'epsilon': 0.551}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:48,160] Trial 8 finished with value: -0.44313577222133677 and parameters: {'C': 8.2, 'kernel': 'linear', 'gamma': 7.1000000000000005, 'epsilon': 0.321}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:50,827] Trial 9 finished with value: -0.45138978689623094 and parameters: {'C': 5.5, 'kernel': 'linear', 'gamma': 7.300000000000001, 'epsilon': 0.051000000000000004}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:51,476] Trial 10 finished with value: -58.39689283363574 and parameters: {'C': 0.1, 'kernel': 'sigmoid', 'gamma': 10.0, 'epsilon': 0.999}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:52,267] Trial 11 finished with value: -550789.6294986941 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 2.4000000000000004, 'epsilon': 0.6950000000000001}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:53,088] Trial 12 finished with value: -305899.81722730846 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 0.6000000000000001, 'epsilon': 0.8}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:53,666] Trial 13 finished with value: -536018.5724141088 and parameters: {'C': 9.9, 'kernel': 'sigmoid', 'gamma': 2.0, 'epsilon': 0.24}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:54,131] Trial 14 finished with value: -237262.2598825164 and parameters: {'C': 6.3, 'kernel': 'sigmoid', 'gamma': 5.5, 'epsilon': 0.907}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:54,621] Trial 15 finished with value: -456279.75930577563 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 2.3000000000000003, 'epsilon': 0.654}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:55,097] Trial 16 finished with value: -230407.4328504921 and parameters: {'C': 6.2, 'kernel': 'sigmoid', 'gamma': 5.5, 'epsilon': 0.168}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:55,562] Trial 17 finished with value: -290637.5046215005 and parameters: {'C': 7.0, 'kernel': 'sigmoid', 'gamma': 4.4, 'epsilon': 0.39}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:55,692] Trial 18 finished with value: -0.6581144080717489 and parameters: {'C': 9.0, 'kernel': 'sigmoid', 'gamma': 0.0, 'epsilon': 0.5660000000000001}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:56,142] Trial 19 finished with value: -527418.2525357093 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 8.8, 'epsilon': 0.8160000000000001}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:56,611] Trial 20 finished with value: -0.5147916407485211 and parameters: {'C': 4.3999999999999995, 'kernel': 'rbf', 'gamma': 2.2, 'epsilon': 0.168}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:57,129] Trial 21 finished with value: -455189.88221413025 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 2.0, 'epsilon': 0.231}. Best is trial 6 with value: -557862.3894509334.
# [I 2024-09-22 10:43:57,602] Trial 22 finished with value: -588269.4516880662 and parameters: {'C': 9.9, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.378}. Best is trial 22 with value: -588269.4516880662.
# [I 2024-09-22 10:43:58,087] Trial 23 finished with value: -592602.6592383563 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.6, 'epsilon': 0.373}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:43:58,559] Trial 24 finished with value: -426392.1561724226 and parameters: {'C': 8.4, 'kernel': 'sigmoid', 'gamma': 3.8000000000000003, 'epsilon': 0.34500000000000003}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:43:59,036] Trial 25 finished with value: -330963.8940882996 and parameters: {'C': 7.4, 'kernel': 'sigmoid', 'gamma': 6.300000000000001, 'epsilon': 0.394}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:43:59,512] Trial 26 finished with value: -297083.8213565023 and parameters: {'C': 7.0, 'kernel': 'sigmoid', 'gamma': 4.9, 'epsilon': 0.533}. Best is trial 23 with value: -592602.6592383563.
# [I 2024-09-22 10:44:00,002] Trial 27 finished with value: -598507.7013597384 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.179}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:00,482] Trial 28 finished with value: -420948.3111505824 and parameters: {'C': 8.4, 'kernel': 'sigmoid', 'gamma': 2.9000000000000004, 'epsilon': 0.131}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:00,866] Trial 29 finished with value: -0.46393195525296865 and parameters: {'C': 1.3000000000000003, 'kernel': 'rbf', 'gamma': 1.1, 'epsilon': 0.226}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:05,737] Trial 30 finished with value: -0.4519417519218056 and parameters: {'C': 10.0, 'kernel': 'linear', 'gamma': 4.1000000000000005, 'epsilon': 0.006}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:06,490] Trial 31 finished with value: -520271.0475576531 and parameters: {'C': 9.3, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.289}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:07,063] Trial 32 finished with value: -537318.0323621857 and parameters: {'C': 9.4, 'kernel': 'sigmoid', 'gamma': 5.1000000000000005, 'epsilon': 0.40900000000000003}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:07,526] Trial 33 finished with value: -468221.2881626886 and parameters: {'C': 8.6, 'kernel': 'sigmoid', 'gamma': 8.4, 'epsilon': 0.494}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:07,953] Trial 34 finished with value: -0.4842191891865227 and parameters: {'C': 9.5, 'kernel': 'rbf', 'gamma': 1.6, 'epsilon': 0.10200000000000001}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:08,455] Trial 35 finished with value: -351242.98969672667 and parameters: {'C': 7.7, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.352}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:08,927] Trial 36 finished with value: -96704.23178671348 and parameters: {'C': 4.0, 'kernel': 'sigmoid', 'gamma': 4.7, 'epsilon': 0.263}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:10,665] Trial 37 finished with value: -0.4474141396572288 and parameters: {'C': 8.6, 'kernel': 'linear', 'gamma': 6.2, 'epsilon': 0.47200000000000003}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:11,116] Trial 38 finished with value: -0.5768807681919949 and parameters: {'C': 9.5, 'kernel': 'rbf', 'gamma': 3.6, 'epsilon': 0.436}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:11,589] Trial 39 finished with value: -388207.16334727686 and parameters: {'C': 8.1, 'kernel': 'sigmoid', 'gamma': 5.7, 'epsilon': 0.17500000000000002}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:13,473] Trial 40 finished with value: -0.4420624502545209 and parameters: {'C': 7.2, 'kernel': 'linear', 'gamma': 7.800000000000001, 'epsilon': 0.302}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:13,962] Trial 41 finished with value: -558168.4833026279 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 2.7, 'epsilon': 0.624}. Best is trial 27 with value: -598507.7013597384.
# [I 2024-09-22 10:44:14,446] Trial 42 finished with value: -599871.2813134261 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.615}. Best is trial 42 with value: -599871.2813134261.
# [I 2024-09-22 10:44:14,931] Trial 43 finished with value: -588320.0653785786 and parameters: {'C': 9.9, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.593}. Best is trial 42 with value: -599871.2813134261.
# [I 2024-09-22 10:44:15,959] Trial 44 finished with value: -602504.053701971 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.4000000000000004, 'epsilon': 0.597}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:17,338] Trial 45 finished with value: -455382.5487691623 and parameters: {'C': 8.7, 'kernel': 'sigmoid', 'gamma': 4.1000000000000005, 'epsilon': 0.602}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:18,874] Trial 46 finished with value: -501030.11245069356 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 1.5, 'epsilon': 0.741}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:19,632] Trial 47 finished with value: -389064.83868852555 and parameters: {'C': 8.0, 'kernel': 'sigmoid', 'gamma': 3.8000000000000003, 'epsilon': 0.674}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:20,378] Trial 48 finished with value: -498251.85632847407 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.588}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:21,065] Trial 49 finished with value: -0.44779137888888193 and parameters: {'C': 2.0, 'kernel': 'linear', 'gamma': 2.5, 'epsilon': 0.517}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:21,551] Trial 50 finished with value: -165191.66204479587 and parameters: {'C': 5.3, 'kernel': 'sigmoid', 'gamma': 4.6000000000000005, 'epsilon': 0.731}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:22,044] Trial 51 finished with value: -600754.141260461 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.46}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:22,531] Trial 52 finished with value: -544403.365848628 and parameters: {'C': 9.5, 'kernel': 'sigmoid', 'gamma': 4.1000000000000005, 'epsilon': 0.459}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:23,018] Trial 53 finished with value: -554009.8898993005 and parameters: {'C': 9.6, 'kernel': 'sigmoid', 'gamma': 3.3000000000000003, 'epsilon': 0.556}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:23,538] Trial 54 finished with value: -424311.4935963005 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 1.7000000000000002, 'epsilon': 0.637}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:24,044] Trial 55 finished with value: -568306.6201866537 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 2.6, 'epsilon': 0.7000000000000001}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:24,429] Trial 56 finished with value: -0.6493859365189906 and parameters: {'C': 9.2, 'kernel': 'rbf', 'gamma': 3.7, 'epsilon': 0.775}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:24,918] Trial 57 finished with value: -235436.781207568 and parameters: {'C': 6.3, 'kernel': 'sigmoid', 'gamma': 4.3, 'epsilon': 0.51}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:25,404] Trial 58 finished with value: -559137.0065343828 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 3.0, 'epsilon': 0.5640000000000001}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:25,909] Trial 59 finished with value: -457524.26174567157 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 2.2, 'epsilon': 0.422}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:26,387] Trial 60 finished with value: -401213.3789537899 and parameters: {'C': 8.2, 'kernel': 'sigmoid', 'gamma': 5.2, 'epsilon': 0.594}. Best is trial 44 with value: -602504.053701971.
# [I 2024-09-22 10:44:26,877] Trial 61 finished with value: -607780.1194238723 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.5, 'epsilon': 0.362}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:27,359] Trial 62 finished with value: -601012.0324420196 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.4000000000000004, 'epsilon': 0.34800000000000003}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:27,830] Trial 63 finished with value: -520679.21141541144 and parameters: {'C': 9.3, 'kernel': 'sigmoid', 'gamma': 3.9000000000000004, 'epsilon': 0.341}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:28,333] Trial 64 finished with value: -548842.2168828282 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 2.7, 'epsilon': 0.366}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:28,806] Trial 65 finished with value: -58054.79293540269 and parameters: {'C': 3.1, 'kernel': 'sigmoid', 'gamma': 3.5, 'epsilon': 0.465}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:29,314] Trial 66 finished with value: -422222.40348371706 and parameters: {'C': 8.9, 'kernel': 'sigmoid', 'gamma': 1.9000000000000001, 'epsilon': 0.488}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:29,794] Trial 67 finished with value: -523775.7969073887 and parameters: {'C': 9.3, 'kernel': 'sigmoid', 'gamma': 4.5, 'epsilon': 0.2}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:30,350] Trial 68 finished with value: -0.5462254023101568 and parameters: {'C': 10.0, 'kernel': 'rbf', 'gamma': 3.0, 'epsilon': 0.269}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:33,375] Trial 69 finished with value: -0.4467900409002718 and parameters: {'C': 7.7, 'kernel': 'linear', 'gamma': 1.1, 'epsilon': 0.398}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:34,129] Trial 70 finished with value: -434475.3969667024 and parameters: {'C': 8.5, 'kernel': 'sigmoid', 'gamma': 3.5, 'epsilon': 0.315}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:34,681] Trial 71 finished with value: -563047.5930359515 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 3.2, 'epsilon': 0.537}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:35,172] Trial 72 finished with value: -562203.8587457169 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 2.4000000000000004, 'epsilon': 0.655}. Best is trial 61 with value: -607780.1194238723.
# [I 2024-09-22 10:44:35,673] Trial 73 finished with value: -609468.262535682 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 4.0, 'epsilon': 0.621}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:44:36,148] Trial 74 finished with value: -517385.97092437913 and parameters: {'C': 9.4, 'kernel': 'sigmoid', 'gamma': 4.0, 'epsilon': 0.066}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:44:36,633] Trial 75 finished with value: -1487.3003666495813 and parameters: {'C': 0.5, 'kernel': 'sigmoid', 'gamma': 4.3, 'epsilon': 0.448}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:44:37,126] Trial 76 finished with value: -201919.5330135187 and parameters: {'C': 5.9, 'kernel': 'sigmoid', 'gamma': 2.8000000000000003, 'epsilon': 0.6980000000000001}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:44:37,626] Trial 77 finished with value: -474366.6735904572 and parameters: {'C': 8.8, 'kernel': 'sigmoid', 'gamma': 4.9, 'epsilon': 0.875}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:44:38,112] Trial 78 finished with value: -515759.19682690315 and parameters: {'C': 9.2, 'kernel': 'sigmoid', 'gamma': 3.6, 'epsilon': 0.329}. Best is trial 73 with value: -609468.262535682.
# [I 2024-09-22 10:44:38,572] Trial 79 finished with value: -614475.0476215199 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 9.8, 'epsilon': 0.425}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:39,297] Trial 80 finished with value: -574690.6211358347 and parameters: {'C': 9.6, 'kernel': 'sigmoid', 'gamma': 9.700000000000001, 'epsilon': 0.421}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:40,443] Trial 81 finished with value: -598400.7372269508 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.2, 'epsilon': 0.374}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:41,234] Trial 82 finished with value: -131459.43470668438 and parameters: {'C': 4.6, 'kernel': 'sigmoid', 'gamma': 9.1, 'epsilon': 0.624}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:42,320] Trial 83 finished with value: -596070.7179196423 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 3.1, 'epsilon': 0.371}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:43,169] Trial 84 finished with value: -546361.212159029 and parameters: {'C': 9.5, 'kernel': 'sigmoid', 'gamma': 3.8000000000000003, 'epsilon': 0.529}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:43,827] Trial 85 finished with value: -503032.5879237243 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 2.8000000000000003, 'epsilon': 0.494}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:48,098] Trial 86 finished with value: -0.4411229544830301 and parameters: {'C': 9.8, 'kernel': 'linear', 'gamma': 2.4000000000000004, 'epsilon': 0.253}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:48,566] Trial 87 finished with value: -0.5894510871411874 and parameters: {'C': 9.4, 'kernel': 'rbf', 'gamma': 7.0, 'epsilon': 0.436}. Best is trial 79 with value: -614475.0476215199.
# [I 2024-09-22 10:44:49,038] Trial 88 finished with value: -618574.1619118742 and parameters: {'C': 10.0, 'kernel': 'sigmoid', 'gamma': 8.0, 'epsilon': 0.404}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:49,499] Trial 89 finished with value: -568326.0978598751 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 7.800000000000001, 'epsilon': 0.28400000000000003}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:49,972] Trial 90 finished with value: -441380.8650828355 and parameters: {'C': 8.4, 'kernel': 'sigmoid', 'gamma': 9.3, 'epsilon': 0.66}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:50,441] Trial 91 finished with value: -605597.0851467741 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.200000000000001, 'epsilon': 0.397}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:50,910] Trial 92 finished with value: -608393.3788562336 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.3, 'epsilon': 0.4}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:51,376] Trial 93 finished with value: -605596.7774656991 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.200000000000001, 'epsilon': 0.41200000000000003}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:51,846] Trial 94 finished with value: -523565.83871383 and parameters: {'C': 9.1, 'kernel': 'sigmoid', 'gamma': 8.200000000000001, 'epsilon': 0.406}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:52,322] Trial 95 finished with value: -570370.634368397 and parameters: {'C': 9.5, 'kernel': 'sigmoid', 'gamma': 8.4, 'epsilon': 0.352}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:52,789] Trial 96 finished with value: -602080.1439836308 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 7.300000000000001, 'epsilon': 0.47200000000000003}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:53,270] Trial 97 finished with value: -477101.7257391604 and parameters: {'C': 8.7, 'kernel': 'sigmoid', 'gamma': 7.300000000000001, 'epsilon': 0.432}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:53,752] Trial 98 finished with value: -607512.3735038352 and parameters: {'C': 9.8, 'kernel': 'sigmoid', 'gamma': 8.700000000000001, 'epsilon': 0.4}. Best is trial 88 with value: -618574.1619118742.
# [I 2024-09-22 10:44:54,226] Trial 99 finished with value: -578828.8730697364 and parameters: {'C': 9.700000000000001, 'kernel': 'sigmoid', 'gamma': 8.0, 'epsilon': 0.481}. Best is trial 88 with value: -618574.1619118742.
# Best Regressor Mean Squared Error: -618574.1619118742
# Best Regressor Parameters:
# C: 10.0
# kernel: sigmoid
# gamma: 8.0
# epsilon: 0.404
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('regressor',
#                  SVR(C=10.0, epsilon=0.404, gamma=8.0, kernel='sigmoid'))])

# %% [markdown]
# * Report the MSE, R2, and MAD of the best SVR on test data.
# * Compare with paper results
#
# The Support Vector Regressor used in the paper by Cortez et al. (2009) used a Gaussian kernel with C = 3, epsilon = \sigma  square root of N, sigma hat = 1.5 / (N * variance), y hat = value predicted by 3NN
#
# Grid Search
#
# The range of hyperparameters that were used were H in [0,11] and gamma in [2^3, 2^1, ..., 2^-15]
#
# 2/3, 1/3 holdout split for validation, sensitivity analysis L=5
#
# evaluate with 20 runs of 5-fold cross validation
#
#
#
#
#
# Paper Results:
# Accuracy:
# T=0.25 -> 43.2 +/- 0.6
# T=0.5  -> 62.4 +/- 0.4
# T=1.0  -> 89.0 +/- 0.2
# MAD = 0.46

# %%
def mad_score(df):
    return abs((df-df.mean(axis=0)).mean(axis=0))


y_train_predict_r = pipeline_r.predict(X_train)
print(f"Regressor Results on Train Set:")
print(f"Test Set Prediction MSE: {mean_squared_error(y_train,y_train_predict_r)}")
print(f"Test Set Prediction R2 Score: {r2_score(y_train,y_train_predict_r)}")
print(f"Test Set Prediction MAD: {mad_score(y_train)}")

y_test_predict_r = pipeline_r.predict(X_test)
print(f"Regressor Results on Test Set:")
print(f"Test Set Prediction MSE: {mean_squared_error(y_test,y_test_predict_r)}")
print(f"Test Set Prediction R2 Score: {r2_score(y_test,y_test_predict_r)}")
print(f"Test Set Prediction MAD: {mad_score(y_test)}")
# Out:
# Regressor Results on Train Set:
# Test Set Prediction MSE: 1065377.494196344
# Test Set Prediction R2 Score: -1630931.0699874666
# Test Set Prediction MAD: quality    1.277897e-16
# dtype: float64
# Regressor Results on Test Set:
# Test Set Prediction MSE: 1048974.2107929613
# Test Set Prediction R2 Score: -1617964.9124130423
# Test Set Prediction MAD: quality    2.960595e-16
# dtype: float64

# %%
for tolerance in tolerances:
    acc_with_tolerance = accuracy_with_tol(y_true, y_pred, tolerance)
    print(f"Accuracy with Tolerance, T = {tolerance}: {acc_with_tolerance}")
# Out:
# Accuracy with Tolerance, T = 0.1: 0.6333333333333333
# Accuracy with Tolerance, T = 0.25: 0.6333333333333333
# Accuracy with Tolerance, T = 0.5: 0.6333333333333333
# Accuracy with Tolerance, T = 1.0: 0.9625

# %% [markdown]
# ## Discussion
# * Based on your results, discuss the difference of treating this problem as classification or regression. How will this decision impact the users of your model?
#
# From this exercise, we saw two different ways on treating this problem. Treating this as a classification, would allow the users to quickly identify wines according to different quality categories making things a bit more straightforward. Based on the results of the classification, the classification model achieved high accuracy, precision and F1 score on the training set but had lower than expected results for the test set. That means the model is able to distinguish the classes of wine qualities well on the training set but is limited on unseen data. Treating this as a regression problem, on the other hand, allows users to predict wine qualities in a more precise manner. Based on the performance of the regression model, the model was able to achieve moderate performance on the training and test set as seen from the MSE, R2, and MAD results. This means that, the model, while not able to predict every data point, can provide relatively close estimates from the true value.
